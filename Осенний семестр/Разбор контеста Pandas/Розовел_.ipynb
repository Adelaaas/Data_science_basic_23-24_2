# %%
import pandas as pd
df = pd.read_csv('students_info.csv')
df

# %%
import pandas as pd
df = pd.read_csv('exams_info.csv')
df

# %%
import pandas as pd
df = pd.read_csv('input.csv')
df
# Out:
#       STD_ID Пол Статус Дата выпуска Категория обучения Форма обучения  \
# 0      99136   Ж    ВЫП   2019-08-31                 БП              Д
# 1      99112   Ж    ВЫП   2019-08-31                 БП              Д
# 2      99109   Ж    ВЫП   2019-08-31                 БП              Д
# 3      99125   Ж    ВЫП   2019-08-31                 БП              Д
# 4     100676   М    ВЫП   2019-08-31                 БП              Д
# ...      ...  ..    ...          ...                ...            ...
# 5461  100678   Ж     СТ          NaN                 БП              Д
# 5462  100663   Ж     СТ          NaN                ДОГ              Д
# 5463  191630   Ж     СТ          NaN                ДОГ              Д
# 5464  191625   Ж     СТ          NaN                ДОГ              Д
# 5465  194978   Ж     СТ          NaN                ДОГ              Д
#
#           Шифр направление (специальность) Образование          Дата выдачи  \
# ...

# %%
s = df[ df["Статус"] == "СТ"]
d = s[ "STD_ID" ]. unique()
num_rows = d.shape[0]
print(num_rows)

s = df[df['Статус'] == "ВЫП"]
d=s['STD_ID'].unique()
print(len(d))

s=df[df['Пол']=="М"]
print(s["направление (специальность)"].value_counts().idxmax())

s=df[df['Пол']=="Ж"]
print(s["направление (специальность)"].value_counts().idxmin())

s = df[ df.drop(columns = ["STD_ID"]).isna().all (axis = 1)]
print(s[ "STD_ID" ].values[0])

s = df.dropna (subset = ['направление (специальность)'])
print(len(s['направление (специальность)'].unique()))

print(df["Пол"].value_counts().idxmax())
# Out:
# 4648
# 455
# Лечебное дело
# Эксплуатация транспортно-технологических машин и комплексов
# 92222
# 44
# Ж
