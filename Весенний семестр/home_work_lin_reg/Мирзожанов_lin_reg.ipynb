# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import subplot as sb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-a30c29084370> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
# ----> 5 import subplot as sb
#
# ModuleNotFoundError: No module named 'subplot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# https://www.kaggle.com/datasets/gauravduttakiit/bike-sharing

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('day.csv')

# %% [markdown]
# **Анализ данных**

# %%
df
# Out:
#      instant     dteday season  yr mnth  holiday weekday  workingday  \
# 0          1 2018-01-01      1   0    1        0       6           0
# 1          2 2018-02-01      1   0    1        0       0           0
# 2          3 2018-03-01      1   0    1        0       1           1
# 3          4 2018-04-01      1   0    1        0       2           1
# 4          5 2018-05-01      1   0    1        0       3           1
# ..       ...        ...    ...  ..  ...      ...     ...         ...
# 725      726 2019-12-27      1   1   12        0       4           1
# 726      727 2019-12-28      1   1   12        0       5           1
# 727      728 2019-12-29      1   1   12        0       6           0
# 728      729 2019-12-30      1   1   12        0       0           0
# 729      730 2019-12-31      1   1   12        0       1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
df.shape
# Out:
# (730, 16)

# %%
df.isna().sum()
#Пустых данных в датафрейме нет
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# 'instant' - номер записи,
#
#  'dteday' - дата,
#
#  'season' - сезон(1:весна, 2:лето, 3:осень, 4:зима),
#
#  'yr' - год(первый или второй),
#
#  'mnth' - месяц,
#
#  'holiday' - являелся ли этот день выходным,
#
#  'weekday' - день недели,
#
#  'workingday' - является ли день рабочим,
#
#  'weathersit' - погодные условия
#
#     - 1: ясно, небольшая облачность, переменная облачность, переменная облачность.
#     - 2: Туман + Облачно, Туман + Разрывы облаков, Туман + Мало облаков, Туман
#     - 3: Небольшой снег, Небольшой дождь + Гроза + Рассеянные облака, Небольшой дождь + Рассеянные облака.
#     - 4: Сильный дождь + Ледяные поддоны + Гроза + Туман, Снег + Туман,
#
#  'temp' - температура в градусах Цельсия,
#
#  'atemp' - ощущаемая температура,
#
#  'hum' - влажность воздуха,
#
#  'windspeed' - скорость ветра,
#
#  'casual' - количество случайных пользователей,
#
#  'registered' - количество зареганных пользователей,
#
#  'cnt' - общее количество арендованных велосипедов

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
df['dteday'] = pd.to_datetime(df['dteday'])
df['season'] = df['season'].astype("category")
df['weekday'] = df['weekday'].astype("category")
df['mnth'] = df['mnth'].astype("category")

# %%
df.info

# %%
df.describe()
# Out:
#           instant          yr     holiday  workingday  weathersit        temp  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    0.500000    0.028767    0.683562    1.394521   20.319259
# std    210.877136    0.500343    0.167266    0.465405    0.544807    7.506729
# min      1.000000    0.000000    0.000000    0.000000    1.000000    2.424346
# 25%    183.250000    0.000000    0.000000    0.000000    1.000000   13.811885
# 50%    365.500000    0.500000    0.000000    1.000000    1.000000   20.465826
# 75%    547.750000    1.000000    0.000000    1.000000    2.000000   26.880615
# max    730.000000    1.000000    1.000000    1.000000    3.000000   35.328347
#
#             atemp         hum   windspeed       casual   registered  \
# count  730.000000  730.000000  730.000000   730.000000   730.000000
# mean    23.726322   62.765175   12.763620   849.249315  3658.757534
# ...

# %%
df.corr()
# Out:
# <ipython-input-24-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              instant        yr   holiday  workingday  weathersit      temp  \
# instant     1.000000  0.866026  0.016275   -0.004619   -0.021862  0.150738
# yr          0.866026  1.000000  0.008195   -0.002945   -0.050322  0.048789
# holiday     0.016275  0.008195  1.000000   -0.252948   -0.034395 -0.028764
# workingday -0.004619 -0.002945 -0.252948    1.000000    0.060236  0.053470
# weathersit -0.021862 -0.050322 -0.034395    0.060236    1.000000 -0.119503
# temp        0.150738  0.048789 -0.028764    0.053470   -0.119503  1.000000
# atemp       0.152773  0.047215 -0.032703    0.052940   -0.120559  0.991696
# hum         0.016080 -0.112547 -0.015662    0.023202    0.590277  0.128565
# ...

# %%
plt.figure(figsize=(13,13), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)
plt.title('Correlogram', fontsize=22)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.show()
# Out:
# <ipython-input-25-d5f74aeb4db3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# %% [markdown]
# На графике видно, что cnt коррелирует с номером записи, но это ничто иное, как совпадение, так как номер записи не несёт никакого смысла. Также хорошо видна зависимость cnt от сезона года, месяца или дня недели, что также очевидно. cnt ещё зависит от погодных условий: прямая корреляция с температурой воздуха, и обратная со скоростью ветра и с погодными условиями. Сильная корреляция также с количесвом случайных и зареганных пользователей, что также очевидно, ведь  они в сумме дают как раз-таки cnt

# %%
fig, axes = plt.subplots(3,7,figure=(20,12))
sns

# %%
fig, axes = plt.subplots(3, 4, figsize=(20,15))
sb.boxplot(data['season'], ax=axes[0][0], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Density')
sb.boxplot(data['yr'], ax=axes[0][1], width=0.3, color=(0.6, 0.4, 0.7)).set_title('BodyFat')
sb.boxplot(data['mnth'], ax=axes[0][2], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Age')
sb.boxplot(data['holiday'], ax=axes[0][3], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Weight')
sb.boxplot(data['weekday'], ax=axes[1][0], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Height')
sb.boxplot(data['workingday'], ax=axes[1][1], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Neck')
sb.boxplot(data['weathersit'], ax=axes[1][2], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Chest')
sb.boxplot(data['temp'], ax=axes[1][3], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Abdomen')
sb.boxplot(data['atemp'], ax=axes[2][0], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Hip')
sb.boxplot(data['hum'], ax=axes[2][1], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Thigh')
sb.boxplot(data['windspeed'], ax=axes[2][2], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Knee')
sb.boxplot(data['casual'], ax=axes[2][3], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Ankle')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ecbbd0a06a30> in <cell line: 2>()
#       1 fig, axes = plt.subplots(3, 4, figsize=(20,15))
# ----> 2 sb.boxplot(data['season'], ax=axes[0][0], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Density')
#       3 sb.boxplot(data['yr'], ax=axes[0][1], width=0.3, color=(0.6, 0.4, 0.7)).set_title('BodyFat')
#       4 sb.boxplot(data['mnth'], ax=axes[0][2], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Age')
#       5 sb.boxplot(data['holiday'], ax=axes[0][3], width=0.3, color=(0.6, 0.4, 0.7)).set_title('Weight')
#
# NameError: name 'sb' is not defined

# %% [markdown]
# **Линейная регрессия**

# %%
X = df.drop(columns=['instant','atemp','dteday','cnt'])
Y = df['cnt']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1/3, random_state=42)
print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Test dataset size: {X_test.shape}, {y_test.shape}')
# Out:
# Train dataset size: (486, 12), (486,)
# Test dataset size: (244, 12), (244,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Веса всех признаков (w1, ..., w13): ', model.coef_)
print('Свободный коэффицент уравнения w0:', model.intercept_)
# Out:
# Веса всех признаков (w1, ..., w13):  [ 2.55644950e-13 -1.14352972e-12 -6.14031395e-14  1.01542298e-12
#   1.91885895e-14  3.18566742e-13  5.07869048e-13  1.89778748e-15
#   4.44175946e-15  2.38546162e-15  1.00000000e+00  1.00000000e+00]
# Свободный коэффицент уравнения w0: -1.8189894035458565e-12

# %%
features = X_train.columns
coeff_df = pd.DataFrame(model.coef_, columns=['Coefficient'])
coeff_df['features'] = features
coeff_df.sort_values(by='Coefficient')
# Out:
#      Coefficient    features
# 1  -1.143530e-12          yr
# 2  -6.140314e-14        mnth
# 7   1.897787e-15        temp
# 9   2.385462e-15   windspeed
# 8   4.441759e-15         hum
# 4   1.918859e-14     weekday
# 0   2.556450e-13      season
# 5   3.185667e-13  workingday
# 6   5.078690e-13  weathersit
# 3   1.015423e-12     holiday
# 11  1.000000e+00  registered
# 10  1.000000e+00      casual

# %%
y_pred = model.predict(X_test)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 5.637020904703336e-13
# Mean Squared Error: 5.803082734430904e-25
# R2 score: 1.0

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 5.637020904703336e-13
# Mean Squared Error: 5.803082734430904e-25
# R2 score: 1.0

# %% [markdown]
# А теперь обучим нашу модель, исключив стобцы casual и registred,тк они в сумме выдают сам ответ, что нелогично

# %%
X = df.drop(columns=['instant','dteday','cnt','casual','registered'])
Y = df['cnt']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=1/5, random_state=42)
print(f'Train dataset size: {X_train.shape}, {y_train.shape}')
print(f'Test dataset size: {X_test.shape}, {y_test.shape}')
# Out:
# Train dataset size: (584, 11), (584,)
# Test dataset size: (146, 11), (146,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Веса всех признаков (w1, ..., w13): ', model.coef_)
print('Свободный коэффицент уравнения w0:', model.intercept_)
# Out:
# Веса всех признаков (w1, ..., w13):  [ 529.5315977  1999.66187871  -48.84870465 -487.52517591   67.96557526
#   149.57107556 -605.28299474  -28.82427649  145.81300538   -9.6777857
#   -35.93714258]
# Свободный коэффицент уравнения w0: 1214.5350761110749

# %%
features = X_train.columns
coeff_df = pd.DataFrame(model.coef_, columns=['Coefficient'])
coeff_df['features'] = features
coeff_df.sort_values(by='Coefficient')
# Out:
#     Coefficient    features
# 6   -605.282995  weathersit
# 3   -487.525176     holiday
# 2    -48.848705        mnth
# 10   -35.937143   windspeed
# 7    -28.824276        temp
# 9     -9.677786         hum
# 4     67.965575     weekday
# 8    145.813005       atemp
# 5    149.571076  workingday
# 0    529.531598      season
# 1   1999.661879          yr

# %%
y_pred = model.predict(X_test)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 570.7139049879678
# Mean Squared Error: 562913.0197910962
# R2 score: 0.8355422116950035

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print('Mean Absolute Error:', mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', mean_squared_error(y_test, y_pred))
print('R2 score:', r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 570.7139049879678
# Mean Squared Error: 562913.0197910962
# R2 score: 0.8355422116950035
